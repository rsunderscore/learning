# %% [markdown]
# # 8 more useful pandas functions
# saved to pocket - original link:
# https://towardsdatascience.com/8-more-useful-pandas-functionalities-for-your-analyses-ef87dcfe5d74?utm_source=pocket_mylist

# %%
import numpy as np
import pandas as pd

# %%
a1 = np.random.randn(10)
a2 = np.random.uniform(0,10, 10)
a3 = np.random.normal(1,10,10)

# %%
b = np.stack([a1, a2, a2])
b.shape
# Out:
# (3, 10)

# %%
df = pd.DataFrame(b.T, columns=['a', 'b', 'c'])
df
# Out:
#           a         b         c
# 0  0.430352  8.352021  8.352021
# 1  1.620633  3.143271  3.143271
# 2  0.013097  9.838322  9.838322
# 3  1.870984  8.037098  8.037098
# 4 -1.628585  6.678317  6.678317
# 5  0.842607  7.025620  7.025620
# 6  0.169366  6.997990  6.997990
# 7  0.116069  8.173352  8.173352
# 8  0.253232  3.416549  3.416549
# 9 -0.606079  7.584760  7.584760

# %% [markdown]
# ## nsmallest/nlargest

# %%
df.nlargest?

# %%
df.nlargest(3, ['a','b'], keep='all')
# Out:
#           a         b         c
# 3  1.870984  8.037098  8.037098
# 1  1.620633  3.143271  3.143271
# 5  0.842607  7.025620  7.025620

# %%
df.nsmallest?

# %%
df.nsmallest(3, 'c', keep='all')
# Out:
#           a         b         c
# 1  1.620633  3.143271  3.143271
# 8  0.253232  3.416549  3.416549
# 4 -1.628585  6.678317  6.678317

# %% [markdown]
# ## hide_index/hide_columns
# - hide_index (hides index labels)
# - hide columns (hides the labels and values???)

# %%
df.style.hide_columns(['c'])
# Out:
# <style  type="text/css" >
# </style><table id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >a</th>        <th class="col_heading level0 col1" >b</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row0_col0" class="data row0 col0" >0.430352</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row0_col1" class="data row0 col1" >8.352021</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row1_col0" class="data row1 col0" >1.620633</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row1_col1" class="data row1 col1" >3.143271</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row2_col0" class="data row2 col0" >0.013097</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row2_col1" class="data row2 col1" >9.838322</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row3_col0" class="data row3 col0" >1.870984</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row3_col1" class="data row3 col1" >8.037098</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row4_col0" class="data row4 col0" >-1.628585</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row4_col1" class="data row4 col1" >6.678317</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row5_col0" class="data row5 col0" >0.842607</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row5_col1" class="data row5 col1" >7.025620</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row6_col0" class="data row6 col0" >0.169366</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row6_col1" class="data row6 col1" >6.997990</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row7_col0" class="data row7 col0" >0.116069</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row7_col1" class="data row7 col1" >8.173352</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row8_col0" class="data row8 col0" >0.253232</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row8_col1" class="data row8 col1" >3.416549</td>
#                     </tr>
#             <tr>
#                         <th id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row9_col0" class="data row9 col0" >-0.606079</td>
#                         <td id="T_ca0156a1_766a_11ec_9a72_1c1b0dcf2069row9_col1" class="data row9 col1" >7.584760</td>
#                     </tr>
#     </tbody></table>

# %%
df.style.hide_index().hidden_index
# Out:
# True

# %%
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069" ><thead>    <tr>        <th class="col_heading level0 col0" >a</th>        <th class="col_heading level0 col1" >b</th>        <th class="col_heading level0 col2" >c</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row0_col0" class="data row0 col0" >0.430352</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row0_col1" class="data row0 col1" >8.352021</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row0_col2" class="data row0 col2" >8.352021</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row1_col0" class="data row1 col0" >1.620633</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row1_col1" class="data row1 col1" >3.143271</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row1_col2" class="data row1 col2" >3.143271</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row2_col0" class="data row2 col0" >0.013097</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row2_col1" class="data row2 col1" >9.838322</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row2_col2" class="data row2 col2" >9.838322</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row3_col0" class="data row3 col0" >1.870984</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row3_col1" class="data row3 col1" >8.037098</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row3_col2" class="data row3 col2" >8.037098</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row4_col0" class="data row4 col0" >-1.628585</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row4_col1" class="data row4 col1" >6.678317</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row4_col2" class="data row4 col2" >6.678317</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row5_col0" class="data row5 col0" >0.842607</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row5_col1" class="data row5 col1" >7.025620</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row5_col2" class="data row5 col2" >7.025620</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row6_col0" class="data row6 col0" >0.169366</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row6_col1" class="data row6 col1" >6.997990</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row6_col2" class="data row6 col2" >6.997990</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row7_col0" class="data row7 col0" >0.116069</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row7_col1" class="data row7 col1" >8.173352</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row7_col2" class="data row7 col2" >8.173352</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row8_col0" class="data row8 col0" >0.253232</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row8_col1" class="data row8 col1" >3.416549</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row8_col2" class="data row8 col2" >3.416549</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row9_col0" class="data row9 col0" >-0.606079</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row9_col1" class="data row9 col1" >7.584760</td>
#                         <td id="T_ca05e760_766a_11ec_9de0_1c1b0dcf2069row9_col2" class="data row9 col2" >7.584760</td>
#             </tr>
#     </tbody></table>

# %%
df.set_index('a').style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069" ><thead>    <tr>        <th class="col_heading level0 col0" >b</th>        <th class="col_heading level0 col1" >c</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row0_col0" class="data row0 col0" >8.352021</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row0_col1" class="data row0 col1" >8.352021</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row1_col0" class="data row1 col0" >3.143271</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row1_col1" class="data row1 col1" >3.143271</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row2_col0" class="data row2 col0" >9.838322</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row2_col1" class="data row2 col1" >9.838322</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row3_col0" class="data row3 col0" >8.037098</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row3_col1" class="data row3 col1" >8.037098</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row4_col0" class="data row4 col0" >6.678317</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row4_col1" class="data row4 col1" >6.678317</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row5_col0" class="data row5 col0" >7.025620</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row5_col1" class="data row5 col1" >7.025620</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row6_col0" class="data row6 col0" >6.997990</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row6_col1" class="data row6 col1" >6.997990</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row7_col0" class="data row7 col0" >8.173352</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row7_col1" class="data row7 col1" >8.173352</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row8_col0" class="data row8 col0" >3.416549</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row8_col1" class="data row8 col1" >3.416549</td>
#             </tr>
#             <tr>
#                                 <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row9_col0" class="data row9 col0" >7.584760</td>
#                         <td id="T_ca087daf_766a_11ec_97e7_1c1b0dcf2069row9_col1" class="data row9 col1" >7.584760</td>
#             </tr>
#     </tbody></table>

# %%
# can't hide a row?

# %% [markdown]
# ## query
# - more convenient and readable than boolean filters e.g. `df[(df["a"] > 5) & (df["b"] < 3)]`

# %%
df.query("a < 0 and b> 5")
# Out:
#           a         b         c
# 4 -1.628585  6.678317  6.678317
# 9 -0.606079  7.584760  7.584760

# %%
df['bool'] = np.random.randint(0,2,10)
df
# Out:
#           a         b         c  bool
# 0  0.430352  8.352021  8.352021     1
# 1  1.620633  3.143271  3.143271     0
# 2  0.013097  9.838322  9.838322     0
# 3  1.870984  8.037098  8.037098     1
# 4 -1.628585  6.678317  6.678317     0
# 5  0.842607  7.025620  7.025620     1
# 6  0.169366  6.997990  6.997990     1
# 7  0.116069  8.173352  8.173352     1
# 8  0.253232  3.416549  3.416549     0
# 9 -0.606079  7.584760  7.584760     0

# %%
df.query('bool') # returns everything and something funny with the index
# Out:
#           a         b         c  bool
# 1  1.620633  3.143271  3.143271     0
# 0  0.430352  8.352021  8.352021     1
# 0  0.430352  8.352021  8.352021     1
# 1  1.620633  3.143271  3.143271     0
# 0  0.430352  8.352021  8.352021     1
# 1  1.620633  3.143271  3.143271     0
# 1  1.620633  3.143271  3.143271     0
# 1  1.620633  3.143271  3.143271     0
# 0  0.430352  8.352021  8.352021     1
# 0  0.430352  8.352021  8.352021     1

# %%
#fails if one of the values is na
df.iloc[5, 'bool'] == None
try:
    df.query('bool') # 
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1368         else:
# -> 1369             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1370
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-278-8544b457e9eb> in <module>
#       1 #fails if one of the values is na
# ----> 2 df.iloc[5, 'bool'] == None
#       3 try:
#       4     df.query('bool') #
#       5 except Exception as e:
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     702                 self._validate_key(k, i)
#     703             except ValueError as err:
# --> 704                 raise ValueError(
#     705                     "Location based indexing can only have "
#     706                     f"[{self._valid_types}] types"
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
#still works if a compare is provided
df.query('bool == True')
# Out:
#           a         b         c  bool
# 0  0.430352  8.352021  8.352021     1
# 3  1.870984  8.037098  8.037098     1
# 5  0.842607  7.025620  7.025620     1
# 6  0.169366  6.997990  6.997990     1
# 7  0.116069  8.173352  8.173352     1

# %% [markdown]
# ## first_valid_index/last_valid_index

# %%
df.first_valid_index(), df.last_valid_index()
# Out:
# (0, 9)

# %%
df.loc[8:10, 'b'] = None
df
# Out:
#           a         b         c  bool
# 0  0.430352  8.352021  8.352021     1
# 1  1.620633  3.143271  3.143271     0
# 2  0.013097  9.838322  9.838322     0
# 3  1.870984  8.037098  8.037098     1
# 4 -1.628585  6.678317  6.678317     0
# 5  0.842607  7.025620  7.025620     1
# 6  0.169366  6.997990  6.997990     1
# 7  0.116069  8.173352  8.173352     1
# 8  0.253232       NaN  3.416549     0
# 9 -0.606079       NaN  7.584760     0

# %%
df.first_valid_index(), df.last_valid_index()
# Out:
# (0, 9)

# %%
df.loc[df['b'].last_valid_index()].to_frame().T
# Out:
#           a         b         c  bool
# 7  0.116069  8.173352  8.173352   1.0

# %% [markdown]
# ## is_monotonic/is_montonic_decreasing
# - "the functions do not check strict monotonicity. It means they allow for duplicate values"

# %%
df['a'].is_monotonic
# Out:
# False

# %%
df['a'].sort_values().is_monotonic
# Out:
# True

# %%
df['b'].is_monotonic_decreasing
# Out:
# False

# %%
df['b'].sort_values(ascending=False).is_monotonic_decreasing #returns false if there are NaNs
# Out:
# False

# %%
df['a'].sort_values(ascending=False).is_monotonic_decreasing #returns false if there are NaNs
# Out:
# True

# %% [markdown]
# ## replace

# %%
df.replace(0,1)
# Out:
#           a         b         c  bool
# 0  0.430352  8.352021  8.352021     1
# 1  1.620633  3.143271  3.143271     1
# 2  0.013097  9.838322  9.838322     1
# 3  1.870984  8.037098  8.037098     1
# 4 -1.628585  6.678317  6.678317     1
# 5  0.842607  7.025620  7.025620     1
# 6  0.169366  6.997990  6.997990     1
# 7  0.116069  8.173352  8.173352     1
# 8  0.253232       NaN  3.416549     1
# 9 -0.606079       NaN  7.584760     1

# %%
df.replace(np.NAN, 999) #replicate fillna (None does not work for this)
# Out:
#           a           b         c  bool
# 0  0.430352    8.352021  8.352021     1
# 1  1.620633    3.143271  3.143271     0
# 2  0.013097    9.838322  9.838322     0
# 3  1.870984    8.037098  8.037098     1
# 4 -1.628585    6.678317  6.678317     0
# 5  0.842607    7.025620  7.025620     1
# 6  0.169366    6.997990  6.997990     1
# 7  0.116069    8.173352  8.173352     1
# 8  0.253232  999.000000  3.416549     0
# 9 -0.606079  999.000000  7.584760     0

# %%
df.replace({'bool':{0:1, 1:0}, 'b':{np.NAN:0}, 'a':{0.358254: 0}}) 
#a doesn't replace because there are more decimals than printed
# Out:
#           a         b         c  bool
# 0  0.430352  8.352021  8.352021     0
# 1  1.620633  3.143271  3.143271     1
# 2  0.013097  9.838322  9.838322     1
# 3  1.870984  8.037098  8.037098     0
# 4 -1.628585  6.678317  6.678317     1
# 5  0.842607  7.025620  7.025620     0
# 6  0.169366  6.997990  6.997990     0
# 7  0.116069  8.173352  8.173352     0
# 8  0.253232  0.000000  3.416549     1
# 9 -0.606079  0.000000  7.584760     1

# %% [markdown]
# ## mask/where
# - mask = replace where True
# - where = replace where false

# %%
df.mask(df['a'] < -1, -999)
# Out:
#             a           b           c  bool
# 0    0.430352    8.352021    8.352021     1
# 1    1.620633    3.143271    3.143271     0
# 2    0.013097    9.838322    9.838322     0
# 3    1.870984    8.037098    8.037098     1
# 4 -999.000000 -999.000000 -999.000000  -999
# 5    0.842607    7.025620    7.025620     1
# 6    0.169366    6.997990    6.997990     1
# 7    0.116069    8.173352    8.173352     1
# 8    0.253232         NaN    3.416549     0
# 9   -0.606079         NaN    7.584760     0

# %%
df['a'].mask(df['a'] < -1, 'fred')
# Out:
# 0    0.430352
# 1     1.62063
# 2    0.013097
# 3     1.87098
# 4        fred
# 5    0.842607
# 6    0.169366
# 7    0.116069
# 8    0.253232
# 9   -0.606079
# Name: a, dtype: object

# %%
df.mask(df < 1, '<3')
# Out:
#          a        b        c bool
# 0       <3  8.35202  8.35202    1
# 1  1.62063  3.14327  3.14327   <3
# 2       <3  9.83832  9.83832   <3
# 3  1.87098   8.0371   8.0371    1
# 4       <3  6.67832  6.67832   <3
# 5       <3  7.02562  7.02562    1
# 6       <3  6.99799  6.99799    1
# 7       <3  8.17335  8.17335    1
# 8       <3      NaN  3.41655   <3
# 9       <3      NaN  7.58476   <3

# %%
df.where(df < 3, '>3')
# Out:
#           a   b   c  bool
# 0  0.430352  >3  >3     1
# 1   1.62063  >3  >3     0
# 2  0.013097  >3  >3     0
# 3   1.87098  >3  >3     1
# 4  -1.62859  >3  >3     0
# 5  0.842607  >3  >3     1
# 6  0.169366  >3  >3     1
# 7  0.116069  >3  >3     1
# 8  0.253232  >3  >3     0
# 9 -0.606079  >3  >3     0

# %% [markdown]
# ## clip
# - replace values outside the range with the min or max of the range

# %%
df.clip(0, 3)
# Out:
#           a    b    c  bool
# 0  0.430352  3.0  3.0     1
# 1  1.620633  3.0  3.0     0
# 2  0.013097  3.0  3.0     0
# 3  1.870984  3.0  3.0     1
# 4  0.000000  3.0  3.0     0
# 5  0.842607  3.0  3.0     1
# 6  0.169366  3.0  3.0     1
# 7  0.116069  3.0  3.0     1
# 8  0.253232  NaN  3.0     0
# 9  0.000000  NaN  3.0     0

# %%
df.clip(upper=0)
# Out:
#           a    b    c  bool
# 0  0.000000  0.0  0.0     0
# 1  0.000000  0.0  0.0     0
# 2  0.000000  0.0  0.0     0
# 3  0.000000  0.0  0.0     0
# 4 -1.628585  0.0  0.0     0
# 5  0.000000  0.0  0.0     0
# 6  0.000000  0.0  0.0     0
# 7  0.000000  0.0  0.0     0
# 8  0.000000  NaN  0.0     0
# 9 -0.606079  NaN  0.0     0

# %% [markdown]
# # 9 Useful Pandas Methods You Might Have Not Heard About
#
# https://towardsdatascience.com/9-useful-pandas-methods-you-probably-have-not-heard-about-28ff6c0bceee

# %% [markdown]
# ## hasnans

# %%
df['b'].hasnans
# Out:
# True

# %%
pd.Series([1,2,3, np.nan, 4,5,6]).hasnans
# Out:
# True

# %%
pd.Series([1,2,3, 2., 4,False,6]).hasnans
# Out:
# False

# %% [markdown]
# ## transform
# apply transform to entires serise
# - similar to running a groupby and merging back

# %%
df['total of a'] = df.groupby('bool')['a'].transform(sum)
df
# Out:
#           a         b         c  bool  total of a
# 0  0.430352  8.352021  8.352021     1    3.429378
# 1  1.620633  3.143271  3.143271     0   -0.347702
# 2  0.013097  9.838322  9.838322     0   -0.347702
# 3  1.870984  8.037098  8.037098     1    3.429378
# 4 -1.628585  6.678317  6.678317     0   -0.347702
# 5  0.842607  7.025620  7.025620     1    3.429378
# 6  0.169366  6.997990  6.997990     1    3.429378
# 7  0.116069  8.173352  8.173352     1    3.429378
# 8  0.253232       NaN  3.416549     0   -0.347702
# 9 -0.606079       NaN  7.584760     0   -0.347702

# %%
df.groupby('bool')['b'].transform(pd.Series.mean)>3
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: b, dtype: bool

# %%
#filter based on a hidden aggregate e.g. mean of b grouped by bool
df[df.groupby('bool')['b'].transform(pd.Series.mean)>3]
# Out:
#           a         b         c  bool  total of a
# 0  0.430352  8.352021  8.352021     1    3.429378
# 1  1.620633  3.143271  3.143271     0   -0.347702
# 2  0.013097  9.838322  9.838322     0   -0.347702
# 3  1.870984  8.037098  8.037098     1    3.429378
# 4 -1.628585  6.678317  6.678317     0   -0.347702
# 5  0.842607  7.025620  7.025620     1    3.429378
# 6  0.169366  6.997990  6.997990     1    3.429378
# 7  0.116069  8.173352  8.173352     1    3.429378
# 8  0.253232       NaN  3.416549     0   -0.347702
# 9 -0.606079       NaN  7.584760     0   -0.347702

# %% [markdown]
# ## merge_asof
# mrege but match closest rather than equal - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html
# - can look for closest backward, forward or both

# %%
pd.date_range?

# %%
from datetime import date
df1 = pd.DataFrame(pd.date_range(end=date.today(), periods=70, freq='w', name='dt'))

df1['categories'] = pd.Series(np.random.randint(1,4, 70)).replace({1:'a', 2:'b', 3:'c'})
df1['values'] = np.random.random(70)*100
df1
# Out:
#            dt categories     values
# 0  2020-09-13          b   7.221611
# 1  2020-09-20          b   6.900884
# 2  2020-09-27          b  18.172170
# 3  2020-10-04          b  47.968875
# 4  2020-10-11          b  45.619181
# ..        ...        ...        ...
# 65 2021-12-12          c  30.447140
# 66 2021-12-19          b  51.063846
# 67 2021-12-26          c  14.536371
# 68 2022-01-02          a  12.366721
# 69 2022-01-09          a  23.192128
#
# [70 rows x 3 columns]

# %%
df2 = pd.DataFrame(pd.date_range(end=date.today(), periods=600, freq='d', name='dt')).sample(30)
df2['newvalue'] = np.random.randint(0,100, 30)
df2['categories'] = np.random.randint(1,4,30)#wasn't working directly so added a step
df2['categories'] = df2['categories'].replace({1:'a', 2:'b', 3:'c'})
df2#.info()
# Out:
#             dt  newvalue categories
# 171 2020-11-13        39          b
# 434 2021-08-03        19          a
# 157 2020-10-30         0          b
# 260 2021-02-10        45          a
# 324 2021-04-15        78          b
# 449 2021-08-18        99          c
# 387 2021-06-17        69          b
# 181 2020-11-23        35          c
# 267 2021-02-17        73          b
# 179 2020-11-21        75          c
# 391 2021-06-21        20          b
# 398 2021-06-28        10          b
# 418 2021-07-18        62          c
# 598 2022-01-14        75          a
# 294 2021-03-16        53          b
# 127 2020-09-30        71          c
# 168 2020-11-10        98          c
# 350 2021-05-11        79          b
# 207 2020-12-19        90          b
# 62  2020-07-27         3          b
# 460 2021-08-29        16          c
# 521 2021-10-29        95          b
# 446 2021-08-15        91          a
# 305 2021-03-27        29          c
# 379 2021-06-09        50          c
# 308 2021-03-30        15          a
# 205 2020-12-17        54          c
# 129 2020-10-02        32          b
# 156 2020-10-29        47          c
# 236 2021-01-17         8          c

# %%
pd.merge_asof?

# %%
df3 = pd.merge_asof( df1 , df2.sort_values('dt'), on='dt', by= 'categories', tolerance = pd.Timedelta("7d"), direction='nearest')
#backward direction is default
#result will not have a lot of values in the new column b/c we are also forcing a match on categories
df3.head(30).sort_values('dt') #maps values from the second table to the closest value from the first table
# Out:
#            dt categories     values  newvalue
# 0  2020-09-13          b   7.221611       NaN
# 1  2020-09-20          b   6.900884       NaN
# 2  2020-09-27          b  18.172170      32.0
# 3  2020-10-04          b  47.968875      32.0
# 4  2020-10-11          b  45.619181       NaN
# 5  2020-10-18          c  83.888702       NaN
# 6  2020-10-25          c  57.095950      47.0
# 7  2020-11-01          c  65.459897      47.0
# 8  2020-11-08          b   2.429956      39.0
# 9  2020-11-15          a  58.464277       NaN
# 10 2020-11-22          b  17.433781       NaN
# 11 2020-11-29          b  27.335472       NaN
# 12 2020-12-06          c  87.759067       NaN
# 13 2020-12-13          c  90.545961      54.0
# 14 2020-12-20          c  73.904632      54.0
# 15 2020-12-27          c  63.259245       NaN
# 16 2021-01-03          b  32.652440       NaN
# 17 2021-01-10          c  22.104345       8.0
# 18 2021-01-17          b  66.887761       NaN
# 19 2021-01-24          c  41.934049       8.0
# 20 2021-01-31          b  81.345321       NaN
# 21 2021-02-07          b  44.813468       NaN
# 22 2021-02-14          c  68.498390       NaN
# 23 2021-02-21          b  57.853715      73.0
# 24 2021-02-28          c  83.055396       NaN
# 25 2021-03-07          a  47.822954       NaN
# 26 2021-03-14          b  15.796799      53.0
# 27 2021-03-21          a  73.329924       NaN
# 28 2021-03-28          a  91.656044      15.0
# 29 2021-04-04          a  68.223001      15.0

# %% [markdown]
# ## insert
# - put a new column in the middle of the dataframe (rather than at the end)

# %%
np.random.uniform(0,100,10)
# Out:
# array([82.01817548, 84.35123556, 31.88929364, 59.43457876, 76.03936195,
#         4.36100348, 83.58028447, 27.57003634, 99.04625816, 52.57595307])

# %%
#df = df.drop('first',axis=1)

# %%
df.insert(0, "first", np.random.uniform(0,100,10))

# %%
df
# Out:
#        first         a         b         c  bool  total of a
# 0  89.357665  0.430352  8.352021  8.352021     1    3.429378
# 1  25.621888  1.620633  3.143271  3.143271     0   -0.347702
# 2  18.068967  0.013097  9.838322  9.838322     0   -0.347702
# 3  43.091220  1.870984  8.037098  8.037098     1    3.429378
# 4  95.514002 -1.628585  6.678317  6.678317     0   -0.347702
# 5  55.570069  0.842607  7.025620  7.025620     1    3.429378
# 6  66.095303  0.169366  6.997990  6.997990     1    3.429378
# 7  41.208768  0.116069  8.173352  8.173352     1    3.429378
# 8  38.371009  0.253232       NaN  3.416549     0   -0.347702
# 9  81.787149 -0.606079       NaN  7.584760     0   -0.347702

# %% [markdown]
# ## explode
# expand lists in a column to new rows
#
# to create new columns from a list pass `df['col'].to_list()` to a new dataframe constructor

# %%
df.explode?

# %%
exdf = pd.DataFrame(data={"id": [1, 2], "values": [[1, 2, 3], [4, 5, 6]]})
exdf
# Out:
#    id     values
# 0   1  [1, 2, 3]
# 1   2  [4, 5, 6]

# %%
exdf.explode('values', ignore_index=True)
# Out:
#    id values
# 0   1      1
# 1   1      2
# 2   1      3
# 3   2      4
# 4   2      5
# 5   2      6

# %%
pd.concat( [exdf, pd.DataFrame(exdf['values'].to_list(), columns = ['v1', 'v2', 'v3'])], axis=1)
# Out:
#    id     values  v1  v2  v3
# 0   1  [1, 2, 3]   1   2   3
# 1   2  [4, 5, 6]   4   5   6

# %% [markdown]
# ## str
# various functions to handle manipulations of string columns - somne ofthe matching functions use regex by default others require a `regex=True` setting, if a regex is used you may need to specify flags e.g. `flags=re.I` which is equivalent to `flags=2` if you haven't imported re
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#string-methods
#
# Examples:
#  - str.split
#  - str.replace
#  - str.lower
#  - str.len
#  - str.contains

# %% [markdown]
# ## read_clipboard
# read the clipboard into a dataframe

# %%
pd.read_clipboard()
# Out:
# Empty DataFrame
# Columns: [https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#string-methods]
# Index: []

# %% [markdown]
# ## eval
# use string expressions to efficiently calculate new columns
#
# https://pandas.pydata.org/docs/reference/api/pandas.eval.html
#
# - how complex can the math be - can't use math.sqrt but can use sqrt if imported directly
#     - cannot contain statements only expressions
# - pandas vs python parser

# %%
df.eval("z=a*b")
# Out:
#        first         a         b         c  bool  total of a          z
# 0  89.357665  0.430352  8.352021  8.352021     1    3.429378   3.594313
# 1  25.621888  1.620633  3.143271  3.143271     0   -0.347702   5.094090
# 2  18.068967  0.013097  9.838322  9.838322     0   -0.347702   0.128852
# 3  43.091220  1.870984  8.037098  8.037098     1    3.429378  15.037279
# 4  95.514002 -1.628585  6.678317  6.678317     0   -0.347702 -10.876208
# 5  55.570069  0.842607  7.025620  7.025620     1    3.429378   5.919837
# 6  66.095303  0.169366  6.997990  6.997990     1    3.429378   1.185220
# 7  41.208768  0.116069  8.173352  8.173352     1    3.429378   0.948672
# 8  38.371009  0.253232       NaN  3.416549     0   -0.347702        NaN
# 9  81.787149 -0.606079       NaN  7.584760     0   -0.347702        NaN

# %%
math.exp(math.pi)
# Out:
# 23.140692632779267

# %%
#from math import sqrt, pi #these don't seem to get used
df.eval("z=sqrt(a*b)", parser='pandas')
# Out:
#        first         a         b         c  bool  total of a         z
# 0  89.357665  0.430352  8.352021  8.352021     1    3.429378  1.895867
# 1  25.621888  1.620633  3.143271  3.143271     0   -0.347702  2.257009
# 2  18.068967  0.013097  9.838322  9.838322     0   -0.347702  0.358960
# 3  43.091220  1.870984  8.037098  8.037098     1    3.429378  3.877793
# 4  95.514002 -1.628585  6.678317  6.678317     0   -0.347702       NaN
# 5  55.570069  0.842607  7.025620  7.025620     1    3.429378  2.433071
# 6  66.095303  0.169366  6.997990  6.997990     1    3.429378  1.088678
# 7  41.208768  0.116069  8.173352  8.173352     1    3.429378  0.973998
# 8  38.371009  0.253232       NaN  3.416549     0   -0.347702       NaN
# 9  81.787149 -0.606079       NaN  7.584760     0   -0.347702       NaN

# %% [markdown]
# ## squeeze
# get rid of the index returned by certain operations (typically I do this by using `iloc[0]` this blog is using `values[0]`

# %%
df.loc[df['a']<-1, 'b']
# Out:
# 4    6.678317
# Name: b, dtype: float64

# %%
df.loc[df['a']<-1, 'b'].values[0]
# Out:
# 6.67831678599791

# %%
df.loc[df['a']<-1, 'b'].iloc[0]
# Out:
# 6.67831678599791

# %%
df.loc[df['a']<-1, 'b'].squeeze()
# Out:
# 6.67831678599791
